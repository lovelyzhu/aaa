# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelyzhu/aaa/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly
import pandas as pd
# Load data
#df = pd.read_csv("finance-charts-apple.csv")
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/Mining-BTC-180.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                 Date  Number-transactions  Output-volume(BTC)  \
# 0           0  2017-04-29 00:00:00               341319             4488916
# 1           1  2017-04-30 00:00:00               281489             3918072
# 2           2  2017-05-01 00:00:00               294786             3892124
# 3           3  2017-05-02 00:00:00               333161             4099704
# 4           4  2017-05-03 00:00:00               295149             3425069
#
#    Market-price  Hash-rate  Cost-per-trans-USD  Mining-revenue-USD  \
# 0       3119179    4488916                   9             3119179
# 1       2720216    3918072                  10             2720216
# 2       2878278    3892124                  10             2878278
# 3       3149553    4099704                  10             3149553
# 4       2760373    3425069                  10             2760373
#
#    Transaction-fees-BTC
# 0                   256
# 1                   199
# 2                   228
# ...

# %%
import plotly.graph_objects as go
line1 = go.Scatter(x=df['Date'], y=df['Hash-rate'], name='Hash-rate')
fig  = go.Figure(line1)
fig.show()
plotly.offline.plot(fig, filename='lifeExp.html')

#x=plotly.offline.plot(fig, include_plotlyjs=False, output_type='div')
#text_file = open("sample.txt", "w")
#n = text_file.write(x)
#text_file.close()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                 Date  Number-transactions  Output-volume(BTC)  \
# 0           0  2017-04-29 00:00:00               341319             4488916
# 1           1  2017-04-30 00:00:00               281489             3918072
# 2           2  2017-05-01 00:00:00               294786             3892124
# 3           3  2017-05-02 00:00:00               333161             4099704
# 4           4  2017-05-03 00:00:00               295149             3425069
#
#    Market-price  Hash-rate  Cost-per-trans-USD  Mining-revenue-USD  \
# 0       3119179    4488916                   9             3119179
# 1       2720216    3918072                  10             2720216
# 2       2878278    3892124                  10             2878278
# 3       3149553    4099704                  10             3149553
# 4       2760373    3425069                  10             2760373
#
#    Transaction-fees-BTC
# 0                   256
# 1                   199
# 2                   228
# ...

# %%
df.shape
# Out:
# (179, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            179 non-null    int64
#  1   Date                  179 non-null    object
#  2   Number-transactions   179 non-null    int64
#  3   Output-volume(BTC)    179 non-null    int64
#  4   Market-price          179 non-null    int64
#  5   Hash-rate             179 non-null    int64
#  6   Cost-per-trans-USD    179 non-null    int64
#  7   Mining-revenue-USD    179 non-null    int64
#  8   Transaction-fees-BTC  179 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 12.7+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Number-transactions  Output-volume(BTC)  Market-price  \
# count  179.000000           179.000000        1.790000e+02  1.790000e+02
# mean    89.000000        268576.463687        6.354816e+06  6.923937e+06
# std     51.816986         45980.026930        1.773494e+06  2.589169e+06
# min      0.000000        131875.000000        3.347227e+06  2.720216e+06
# 25%     44.500000        233401.500000        4.939624e+06  5.176342e+06
# 50%     89.000000        267360.000000        6.094384e+06  6.147322e+06
# 75%    133.500000        297181.000000        7.569349e+06  8.410238e+06
# max    178.000000        369098.000000        1.160111e+07  1.421711e+07
#
#           Hash-rate  Cost-per-trans-USD  Mining-revenue-USD  \
# count  1.790000e+02          179.000000        1.790000e+02
# mean   6.354816e+06           27.223464        6.923937e+06
# std    1.773494e+06            9.977802        2.589169e+06
# min    3.347227e+06            9.000000        2.720216e+06
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0       Date  Number-transactions  Output-volume(BTC)  \
# 0           0 2017-04-29               341319             4488916
# 1           1 2017-04-30               281489             3918072
# 2           2 2017-05-01               294786             3892124
# 3           3 2017-05-02               333161             4099704
# 4           4 2017-05-03               295149             3425069
#
#    Market-price  Hash-rate  Cost-per-trans-USD  Mining-revenue-USD  \
# 0       3119179    4488916                   9             3119179
# 1       2720216    3918072                  10             2720216
# 2       2878278    3892124                  10             2878278
# 3       3149553    4099704                  10             3149553
# 4       2760373    3425069                  10             2760373
#
#    Transaction-fees-BTC
# 0                   256
# 1                   199
# 2                   228
# 3                   273
# 4                   247

# %%
type(df.Date)
# Out:
# pandas.core.series.Series

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] > pd.to_datetime('2017-01-01')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 174    True
# 175    True
# 176    True
# 177    True
# 178    True
# Name: Date, Length: 179, dtype: bool

# %%
df1=df[df['Date'] > pd.to_datetime('2017-01-01')]

# %%
line1 = go.Scatter(x=df1['Date'], y=df1['Hash-rate'], name='Hash-rate')
fig  = go.Figure(line1)
fig.show()
plotly.offline.plot(fig, filename='lifeExp1.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
